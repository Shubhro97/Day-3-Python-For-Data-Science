# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhro97/Day-3-Python-For-Data-Science/blob/main/Shubhro_Day_3_Python_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file='https://download.bls.gov/pub/time.series/cu/cu.item'
df=pd.read_csv('https://download.bls.gov/pub/time.series/cu/cu.item', sep='\t')
df.head()
# Out:
#   item_code  ... sort_sequence
# 0       AA0  ...             2
# 1      AA0R  ...           399
# 2       SA0  ...             1
# 3      SA0E  ...           374
# 4     SA0L1  ...           358
#
# [5 rows x 5 columns]

# %%
df['item_name']
# Out:
# 0                                   All items - old base
# 1      Purchasing power of the consumer dollar - old ...
# 2                                              All items
# 3                                                 Energy
# 4                                    All items less food
#                              ...
# 394     Tax return preparation and other accounting fees
# 395                                    College textbooks
# 396             Food at elementary and secondary schools
# 397                                   Infants' equipment
# 398                                   Infants' furniture
# Name: item_name, Length: 399, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_code      399 non-null    object
#  1   item_name      399 non-null    object
#  2   display_level  399 non-null    int64
#  3   selectable     399 non-null    object
#  4   sort_sequence  399 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#        display_level  sort_sequence
# count     399.000000     399.000000
# mean        3.192982     200.000000
# std         1.817102     115.325626
# min         0.000000       1.000000
# 25%         2.000000     100.500000
# 50%         3.000000     200.000000
# 75%         4.000000     299.500000
# max         8.000000     399.000000

# %%
df['item_name'].value_counts()
# Out:
# Rice                                      1
# Household operations                      1
# Gardening and lawncare services           1
# Nondurables less food and apparel         1
# Repair of household items                 1
#                                          ..
# Frozen noncarbonated juices and drinks    1
# Men's apparel                             1
# Prescription drugs                        1
# Fresh cakes and cupcakes                  1
# Uncooked ground beef                      1
# Name: item_name, Length: 399, dtype: int64

# %%
df.corr()
# Out:
#                display_level  sort_sequence
# display_level        1.00000       -0.70548
# sort_sequence       -0.70548        1.00000

# %%
df.dtypes
# Out:
# item_code        object
# item_name        object
# display_level     int64
# selectable       object
# sort_sequence     int64
# dtype: object

# %%
df
# Out:
#     item_code  ... sort_sequence
# 0         AA0  ...             2
# 1        AA0R  ...           399
# 2         SA0  ...             1
# 3        SA0E  ...           374
# 4       SA0L1  ...           358
# ..        ...  ...           ...
# 394   SS68023  ...           352
# 395   SSEA011  ...           314
# 396  SSFV031A  ...           122
# 397   SSGE013  ...           355
# 398   SSHJ031  ...           165
#
# [399 rows x 5 columns]

# %%
df[['item_code', 'display_level']]
# Out:
#     item_code  display_level
# 0         AA0              0
# 1        AA0R              0
# 2         SA0              0
# 3        SA0E              1
# 4       SA0L1              1
# ..        ...            ...
# 394   SS68023              4
# 395   SSEA011              3
# 396  SSFV031A              3
# 397   SSGE013              3
# 398   SSHJ031              3
#
# [399 rows x 2 columns]

# %%
df.iloc[:,3:]
# Out:
#     selectable  sort_sequence
# 0            T              2
# 1            T            399
# 2            T              1
# 3            T            374
# 4            T            358
# ..         ...            ...
# 394          T            352
# 395          T            314
# 396          T            122
# 397          T            355
# 398          T            165
#
# [399 rows x 2 columns]

# %%
df.iloc[:,3:].values
# Out:
# array([['T', 2],
#        ['T', 399],
#        ['T', 1],
#        ['T', 374],
#        ['T', 358],
#        ['T', 361],
#        ['T', 362],
#        ['T', 363],
#        ['T', 359],
#        ['T', 360],
#        ['T', 356],
#        ['T', 357],
#        ['T', 398],
#        ['T', 364],
#        ['T', 187],
#        ['T', 188],
#        ['T', 195],
#        ['T', 365],
#        ['T', 375],
#        ['T', 366],
#        ['T', 367],
#        ['T', 368],
#        ['T', 369],
#        ['T', 371],
#        ['T', 311],
#        ['T', 312],
#        ['T', 320],
#        ['T', 324],
#        ['T', 372],
#        ['T', 373],
#        ['T', 3],
#        ['T', 4],
#        ['T', 5],
#        ['T', 6],
#        ['T', 24],
#        ['T', 25],
#        ['T', 26],
#        ['T', 63],
#        ['T', 64],
#        ['T', 84],
#        ['T', 94],
#        ['T', 125],
#        ['T', 335],
#        ['T', 339],
#        ['T', 383],
#        ['T', 384],
#        ['T', 136],
#        ['T', 137],
# ...

# %%
df.isnull().sum()
# Out:
# item_code        0
# item_name        0
# display_level    0
# selectable       0
# sort_sequence    0
# dtype: int64

# %%
df[df['sort_sequence']>300]
# Out:
#     item_code  ... sort_sequence
# 1        AA0R  ...           399
# 3        SA0E  ...           374
# 4       SA0L1  ...           358
# 5      SA0L12  ...           361
# 6     SA0L12E  ...           362
# ..        ...  ...           ...
# 387   SS62032  ...           306
# 393   SS68021  ...           351
# 394   SS68023  ...           352
# 395   SSEA011  ...           314
# 397   SSGE013  ...           355
#
# [99 rows x 5 columns]

# %%
df.dropna(axis=1)
# Out:
#     item_code  ... sort_sequence
# 0         AA0  ...             2
# 1        AA0R  ...           399
# 2         SA0  ...             1
# 3        SA0E  ...           374
# 4       SA0L1  ...           358
# ..        ...  ...           ...
# 394   SS68023  ...           352
# 395   SSEA011  ...           314
# 396  SSFV031A  ...           122
# 397   SSGE013  ...           355
# 398   SSHJ031  ...           165
#
# [399 rows x 5 columns]

# %%
pd.isna(df['selectable'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# Name: selectable, Length: 399, dtype: bool

# %%
df['selectable'].notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 394    True
# 395    True
# 396    True
# 397    True
# 398    True
# Name: selectable, Length: 399, dtype: bool

# %%
df.fillna('Missing')
# Out:
#     item_code  ... sort_sequence
# 0         AA0  ...             2
# 1        AA0R  ...           399
# 2         SA0  ...             1
# 3        SA0E  ...           374
# 4       SA0L1  ...           358
# ..        ...  ...           ...
# 394   SS68023  ...           352
# 395   SSEA011  ...           314
# 396  SSFV031A  ...           122
# 397   SSGE013  ...           355
# 398   SSHJ031  ...           165
#
# [399 rows x 5 columns]
